# %%
from IPython.display import display, HTML
display(HTML("""
<style>
div.container{width:86% !important;}
div.cell.code_cell.rendered{width:100%;}
div.CodeMirror {font-family:Consolas; font-size:15pt;}
div.output {font-size:15pt; font-weight:bold;}
div.input {font-family:Consolas; font-size:15pt;}
div.prompt {min-width:70px;}
div#toc-wrapper{padding-top:120px;}
div.text_cell_render ul li{font-size:12pt;padding:5px;}
table.dataframe{font-size:15px;}
</style>
"""))
# Out:
# <style>
# div.container{width:86% !important;}
# div.cell.code_cell.rendered{width:100%;}
# div.CodeMirror {font-family:Consolas; font-size:15pt;}
# div.output {font-size:15pt; font-weight:bold;}
# div.input {font-family:Consolas; font-size:15pt;}
# div.prompt {min-width:70px;}
# div#toc-wrapper{padding-top:120px;}
# div.text_cell_render ul li{font-size:12pt;padding:5px;}
# table.dataframe{font-size:15px;}
# </style>

# %% [markdown]
# # 1. 환경(패키지 및 환경변수)
# - pip install openai langchain-openai

# %%
from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %% [markdown]
# # 2. LLM답변 생성
# ## 2.1 openAI SDK를 선택
# - 세밀한 제어가 필요할 때, 성능 최적화가 중요할 때

# %%
from openai import OpenAI
client = OpenAI()
response = client.chat.completions.create(
    model = 'gpt-4.1-nano',
    messages = [
        {'role':'system','content':'너는 친절하게 답해주는 비서야'},
        {'role':'user','content':'2020년 월드시리즈 누가 우승했어?'}
    ]
)

# %%
response.choices[0].message.content
# Out:
# '2020년 월드시리즈는 텍사스 레인저스와 탬파베이 레이스가 맞붙었는데요, 하지만 이때는 월드시리즈가 열리지 않았어요. 대신, 2020년에는 워싱턴 내셔널스가 휴스턴 애스트로스와의 챔피언십 시리즈를 이기고, 애스트로스가 불법 도핑 혐의를 받는 등 여러 논란이 있었어요. \n\n사실, 2020년 메이저리그(MLB) 정규 시즌과 플레이오프는 코로나19 팬데믹으로 인해 정상적인 형식이 아니었고, 월드시리즈는 11월 1일에 탬파베이 레이스가 디트로이트 타이거스와 결승을 치른 후, 탬파베이 레이스가 우승했어요. \n\n즉, 2020년 월드시리즈 우승 팀은 **탬파베이 레이스**입니다!'

# %% [markdown]
# ## 2.2 LangChain을 선택
# - 내부적으로 자동메세지 형태를 변환해 줌

# %%
from langchain_openai import ChatOpenAI
# .env OPEN_API_KEY
llm = ChatOpenAI(
    model = 'gpt-4.1-nano' # 기본모델: gpt-3.5-turbo
)
ai_message = llm.invoke('2020년 월드시리즈 누가 우승했어?')

# %%
ai_message.content
# Out:
# '2020년 월드시리즈는 로스앤젤레스 다저스(LA Dodgers)가 우승을 차지했습니다. 다저스는 텍사스 레인저스를 누르고 시리즈 4승 2패로 우승을 확정지었습니다. 이로써 다저스는 1988년 이후 32년 만에 정상에 올랐으며, 통산 7번째 월드시리즈 우승을 기록했습니다.'
