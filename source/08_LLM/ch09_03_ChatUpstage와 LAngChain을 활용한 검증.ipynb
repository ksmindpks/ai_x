# %%
from IPython.display import display, HTML
display(HTML("""
<style>
div.container{width:86% !important;}
div.cell.code_cell.rendered{width:100%;}
div.CodeMirror {font-family:Consolas; font-size:15pt;}
div.output {font-size:15pt; font-weight:bold;}
div.input {font-family:Consolas; font-size:15pt;}
div.prompt {min-width:70px;}
div#toc-wrapper{padding-top:120px;}
div.text_cell_render ul li{font-size:12pt;padding:5px;}
table.dataframe{font-size:15px;}
</style>
"""))
# Out:
# <style>
# div.container{width:86% !important;}
# div.cell.code_cell.rendered{width:100%;}
# div.CodeMirror {font-family:Consolas; font-size:15pt;}
# div.output {font-size:15pt; font-weight:bold;}
# div.input {font-family:Consolas; font-size:15pt;}
# div.prompt {min-width:70px;}
# div#toc-wrapper{padding-top:120px;}
# div.text_cell_render ul li{font-size:12pt;padding:5px;}
# table.dataframe{font-size:15px;}
# </style>

# %% [markdown]
# # 1. 환경(패키지 및 환경변수)
# - pip install langchain-upstage

# %%
# %pip install -q langchain-upstage
# Out:
# Note: you may need to restart the kernel to use updated packages.

# %%
from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %% [markdown]
# # 2. LLM 답변 생성
# ## 2.1 OpenAI SDK를 사용

# %%
from openai import OpenAI # openai==1.52.2
import os

upstage_api_key = os.getenv('UPSTAGE_API_KEY')

upstage_client = OpenAI(
    api_key=upstage_api_key,
    base_url="https://api.upstage.ai/v1"
)
 
stream = upstage_client.chat.completions.create(
    model="solar-pro2",
    messages=[
        {
            "role": "user",
            "content": "2020년 월드시리즈 누가 우승했어?"
        }
    ],
    stream=False,
)

# %%
print(stream.choices[0].message.content)
# Out:
# 2020년 월드시리즈에서는 **로스앤젤레스 다저스**가 우승했습니다. 다저스는 탬파베이 레이스와 맞붙어 6경기 끝에 4승 2패로 승리하며, 32년 만의 우승을 달성했습니다. 특히 이 시리즈는 코로나19 팬데믹 영향으로 중립 지역인 텍사스 주 알링턴의 글로브 라이프 필드에서 무관중 경기로 진행되었습니다.
#
# - **MVP**: 다저스의 코리 시거(3루수)가 시리즈 MVP로 선정되었으며, 타율 0.333, 2홈런, 6타점을 기록했습니다.
# - **역사적 의미**: 다저스는 프랭크 윌리 화이트 구단주 시절(1958년 이후) 첫 우승을 포함해 통산 7번째 우승을 달성했습니다.
#
# 관련 기록이 궁금하시면 추가로 알려드릴 수 있습니다!

# %% [markdown]
# # 2.2 LangChain을 선택
# - 발급 받은 API Key를 .env에 UPSTAGE_API_KEY라고 저장하면 별도의 설정없이 ChatUpstage를 바로 사용

# %%
from langchain_upstage import ChatUpstage
from langchain_core.messages import SystemMessage, HumanMessage
llm = ChatUpstage()
messages = [
    SystemMessage(content='너는 친절하게 대답해 주는 비서야'),
    HumanMessage(content='2020년 월드 시리즈 누가 우승했어?')
]
ai_message = llm.invoke(input=messages)
ai_message
# Out:
# AIMessage(content='2020년 월드 시리즈는 LA 다저스가 우승했습니다. 그들은 탬파베이 레이스를 4승 2패로 꺾고 32년 만에 월드시리즈 우승을 차지했습니다.', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 44, 'prompt_tokens': 36, 'total_tokens': 80, 'completion_tokens_details': None, 'prompt_tokens_details': None}, 'model_name': 'solar-mini-250422', 'system_fingerprint': None, 'id': 'f3d66ca7-c6d1-4dbd-9376-06151f1a4b9a', 'service_tier': None, 'finish_reason': 'stop', 'logprobs': None}, id='run--660d7663-b237-4591-89e7-f5257016438a-0', usage_metadata={'input_tokens': 36, 'output_tokens': 44, 'total_tokens': 80, 'input_token_details': {}, 'output_token_details': {}})

# %%
ai_message.content
# Out:
# '2020년 월드 시리즈는 LA 다저스가 우승했습니다. 그들은 탬파베이 레이스를 4승 2패로 꺾고 32년 만에 월드시리즈 우승을 차지했습니다.'
