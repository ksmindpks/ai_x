# %%
from IPython.display import display, HTML
display(HTML("""
<style>
div.container{width:86% !important;}
div.cell.code_cell.rendered{width:100%;}
div.CodeMirror {font-family:Consolas; font-size:15pt;}
div.output {font-size:15pt; font-weight:bold;}
div.input {font-family:Consolas; font-size:15pt;}
div.prompt {min-width:70px;}
div#toc-wrapper{padding-top:120px;}
div.text_cell_render ul li{font-size:12pt;padding:5px;}
table.dataframe{font-size:15px;}
</style>
"""))
# Out:
# <style>
# div.container{width:86% !important;}
# div.cell.code_cell.rendered{width:100%;}
# div.CodeMirror {font-family:Consolas; font-size:15pt;}
# div.output {font-size:15pt; font-weight:bold;}
# div.input {font-family:Consolas; font-size:15pt;}
# div.prompt {min-width:70px;}
# div#toc-wrapper{padding-top:120px;}
# div.text_cell_render ul li{font-size:12pt;padding:5px;}
# table.dataframe{font-size:15px;}
# </style>

# %% [markdown]
# # 1. 환경(패키지 및 환경변수)
# - pip install langchain-ollma
# - pip install langchain-community

# %%
# %pip install -q langchain-community
# Out:
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# # 2. LLM 답변 생성
# - https://ollama.com/에서 모델 선택(llama3.2:1b)
# - powershell이사 cmd창에서 ollama pull llama3.2:1b

# %%
from langchain_ollama import ChatOllama
# from langchain_community.chat_models import ChatOllama
llm = ChatOllama(model='llama3.2:1b')
ai_message = llm.invoke('2020년 월드 시리즈에서 누가 우승했나요?')
ai_message.content
# Out:
# '2020년 월드 시리즈는 미국의 NBA 우승자인 뉴욕 نی어스와 한국의 KBO 리그시리즈에서 경쟁했습니다. 뉴욕 뉴저지주의 마이클 크리스티니의 팀은 1-3으로 패하여 KBO 리그시리즈를 이겼다.'

# %% [markdown]
# # 3. 코랩에서 ollama(exaone3.5:2.4b) 돌려보기
# - https://colab.research.google.com/drive/1STz_1Agk017mos4x70V4hZ_8gI46lGvo?usp=sharing
