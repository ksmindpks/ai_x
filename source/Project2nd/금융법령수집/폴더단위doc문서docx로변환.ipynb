# %%
import os
import win32com.client

def convert_doc_to_docx(folder_path):
    word = win32com.client.Dispatch("Word.Application")
    word.Visible = False

    for root, dirs, files in os.walk(folder_path):
        for file in files:
            if file.endswith(".doc") and not file.endswith(".docx"):
                doc_path = os.path.join(root, file)
                docx_path = os.path.splitext(doc_path)[0] + ".docx"

                try:
                    doc = word.Documents.Open(doc_path)
                    doc.SaveAs(docx_path, FileFormat=16)  # 16 = wdFormatDocumentDefault (.docx)
                    doc.Close()
                    print(f"✅ 변환 완료: {doc_path} → {docx_path}")
                except Exception as e:
                    print(f"⚠️ 변환 실패: {doc_path}\n  └ 오류: {e}")

    word.Quit()
    print("🎉 전체 변환 완료.")

# 예시: 실제 사용 시 아래 경로에 압축을 푼 폴더 경로를 입력
if __name__ == "__main__":
    folder_to_convert = r"C:\ai_x\source\Project2nd\금융법령수집\은행_법령_다운로드"  # ← 여기에 폴더 경로 입력
    convert_doc_to_docx(folder_to_convert)
# Out:
# ✅ 변환 완료: C:\ai_x\source\Project2nd\금융법령수집\은행_법령_다운로드\상호저축은행법 시행규칙(총리령)(제01937호)(20240119).doc → C:\ai_x\source\Project2nd\금융법령수집\은행_법령_다운로드\상호저축은행법 시행규칙(총리령)(제01937호)(20240119).docx
# ✅ 변환 완료: C:\ai_x\source\Project2nd\금융법령수집\은행_법령_다운로드\상호저축은행법 시행령(대통령령)(제34124호)(20240119).doc → C:\ai_x\source\Project2nd\금융법령수집\은행_법령_다운로드\상호저축은행법 시행령(대통령령)(제34124호)(20240119).docx
# ✅ 변환 완료: C:\ai_x\source\Project2nd\금융법령수집\은행_법령_다운로드\상호저축은행법(법률)(제20434호)(20250131).doc → C:\ai_x\source\Project2nd\금융법령수집\은행_법령_다운로드\상호저축은행법(법률)(제20434호)(20250131).docx
# ✅ 변환 완료: C:\ai_x\source\Project2nd\금융법령수집\은행_법령_다운로드\수표법 적용 시 은행과 동일시되는 사람 또는 시설의 지정에 관한 규정(대통령령)(제27556호)(20161201).doc → C:\ai_x\source\Project2nd\금융법령수집\은행_법령_다운로드\수표법 적용 시 은행과 동일시되는 사람 또는 시설의 지정에 관한 규정(대통령령)(제27556호)(20161201).docx
# ✅ 변환 완료: C:\ai_x\source\Project2nd\금융법령수집\은행_법령_다운로드\은행법 시행령(대통령령)(제35382호)(20250312).doc → C:\ai_x\source\Project2nd\금융법령수집\은행_법령_다운로드\은행법 시행령(대통령령)(제35382호)(20250312).docx
# ✅ 변환 완료: C:\ai_x\source\Project2nd\금융법령수집\은행_법령_다운로드\은행법(법률)(제19261호)(20230922).doc → C:\ai_x\source\Project2nd\금융법령수집\은행_법령_다운로드\은행법(법률)(제19261호)(20230922).docx
# ✅ 변환 완료: C:\ai_x\source\Project2nd\금융법령수집\은행_법령_다운로드\인터넷전문은행 설립 및 운영에 관한 특례법 시행령(대통령령)(제32274호)(20211230).doc → C:\ai_x\source\Project2nd\금융법령수집\은행_법령_다운로드\인터넷전문은행 설립 및 운영에 관한 특례법 시행령(대통령령)(제32274호)(20211230).docx
# ✅ 변환 완료: C:\ai_x\source\Project2nd\금융법령수집\은행_법령_다운로드\인터넷전문은행 설립 및 운영에 관한 특례법(법률)(제19262호)(20230922).doc → C:\ai_x\source\Project2nd\금융법령수집\은행_법령_다운로드\인터넷전문은행 설립 및 운영에 관한 특례법(법률)(제19262호)(20230922).docx
# ✅ 변환 완료: C:\ai_x\source\Project2nd\금융법령수집\은행_법령_다운로드\중소기업은행법 시행령(대통령령)(제35228호)(20250131).doc → C:\ai_x\source\Project2nd\금융법령수집\은행_법령_다운로드\중소기업은행법 시행령(대통령령)(제35228호)(20250131).docx
# ✅ 변환 완료: C:\ai_x\source\Project2nd\금융법령수집\은행_법령_다운로드\중소기업은행법(법률)(제17112호)(20210325).doc → C:\ai_x\source\Project2nd\금융법령수집\은행_법령_다운로드\중소기업은행법(법률)(제17112호)(20210325).docx
# ✅ 변환 완료: C:\ai_x\source\Project2nd\금융법령수집\은행_법령_다운로드\중소기업은행법제54조제6항시행에관한규정 시행세칙(총리령)(제01712호)(20210630).doc → C:\ai_x\source\Project2nd\금융법령수집\은행_법령_다운로드\중소기업은행법제54조제6항시행에관한규정 시행세칙(총리령)(제01712호)(20210630).docx
# ✅ 변환 완료: C:\ai_x\source\Project2nd\금융법령수집\은행_법령_다운로드\중소기업은행법제54조제6항시행에관한규정(대통령령)(제20653호)(20080229).doc → C:\ai_x\source\Project2nd\금융법령수집\은행_법령_다운로드\중소기업은행법제54조제6항시행에관한규정(대통령령)(제20653호)(20080229).docx
# ✅ 변환 완료: C:\ai_x\source\Project2nd\금융법령수집\은행_법령_다운로드\한국산업은행법 시행령(대통령령)(제35607호)(20250625).doc → C:\ai_x\source\Project2nd\금융법령수집\은행_법령_다운로드\한국산업은행법 시행령(대통령령)(제35607호)(20250625).docx
# ✅ 변환 완료: C:\ai_x\source\Project2nd\금융법령수집\은행_법령_다운로드\한국산업은행법(법률)(제20719호)(20250121).doc → C:\ai_x\source\Project2nd\금융법령수집\은행_법령_다운로드\한국산업은행법(법률)(제20719호)(20250121).docx
# ✅ 변환 완료: C:\ai_x\source\Project2nd\금융법령수집\은행_법령_다운로드\한국수출입은행법 시행령(대통령령)(제35228호)(20250131).doc → C:\ai_x\source\Project2nd\금융법령수집\은행_법령_다운로드\한국수출입은행법 시행령(대통령령)(제35228호)(20250131).docx
# ✅ 변환 완료: C:\ai_x\source\Project2nd\금융법령수집\은행_법령_다운로드\한국수출입은행법(법률)(제19829호)(20240627).doc → C:\ai_x\source\Project2nd\금융법령수집\은행_법령_다운로드\한국수출입은행법(법률)(제19829호)(20240627).docx
# ✅ 변환 완료: C:\ai_x\source\Project2nd\금융법령수집\은행_법령_다운로드\한국은행 정부유가증권취급규칙(기획재정부령)(제00867호)(20211028).doc → C:\ai_x\source\Project2nd\금융법령수집\은행_법령_다운로드\한국은행 정부유가증권취급규칙(기획재정부령)(제00867호)(20211028).docx
# ✅ 변환 완료: C:\ai_x\source\Project2nd\금융법령수집\은행_법령_다운로드\한국은행 통화안정증권법(법률)(제14052호)(20160603).doc → C:\ai_x\source\Project2nd\금융법령수집\은행_법령_다운로드\한국은행 통화안정증권법(법률)(제14052호)(20160603).docx
# ✅ 변환 완료: C:\ai_x\source\Project2nd\금융법령수집\은행_법령_다운로드\한국은행법 시행령(대통령령)(제35228호)(20250131).doc → C:\ai_x\source\Project2nd\금융법령수집\은행_법령_다운로드\한국은행법 시행령(대통령령)(제35228호)(20250131).docx
# ✅ 변환 완료: C:\ai_x\source\Project2nd\금융법령수집\은행_법령_다운로드\한국은행법(법률)(제19409호)(20240517).doc → C:\ai_x\source\Project2nd\금융법령수집\은행_법령_다운로드\한국은행법(법률)(제19409호)(20240517).docx
# 🎉 전체 변환 완료.
