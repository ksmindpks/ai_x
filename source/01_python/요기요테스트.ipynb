# %%
from IPython.display import display, HTML 
display(HTML("""
<style>
div.container{width:86% !important;}
div.cell.code_cell.rendered{width:100%;}
div.CodeMirror {font-family:Consolas; font-size:15pt;}
div.output {font-size:15pt; font-weight:bold;}
div.input {font-family:Consolas; font-size:15pt;}
div.prompt {min-width:70px;}
div#toc-wrapper{padding-top:120px;}
div.text_cell_render ul li{font-size:12pt;padding:5px;}
table.dataframe{font-size:15px;}
</style>
"""))
# Out:
# <style>
# div.container{width:86% !important;}
# div.cell.code_cell.rendered{width:100%;}
# div.CodeMirror {font-family:Consolas; font-size:15pt;}
# div.output {font-size:15pt; font-weight:bold;}
# div.input {font-family:Consolas; font-size:15pt;}
# div.prompt {min-width:70px;}
# div#toc-wrapper{padding-top:120px;}
# div.text_cell_render ul li{font-size:12pt;padding:5px;}
# table.dataframe{font-size:15px;}
# </style>

# %% [markdown]
# import requests
# from bs4 import BeautifulSoup
# import re
#
# response = requests.get('https://www.yogiyo.co.kr/mobile/#/308266/')
# response, response.status_code
# response.text

# %%
# response.text

# %%
soup = BeautifulSoup(response.text, 'html.parser')

# %%
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.common.by import By
from bs4 import BeautifulSoup
import re
import time

# 크롬 드라이버 경로 설정
service = Service('C:\Program Files\Google\Chrome\Application\chrome.exe')  # 👉 크롬드라이버 경로로 수정하세요
driver = webdriver.Chrome(service=service)

# 요기요 매장 페이지 접속
driver.get("https://www.yogiyo.co.kr/mobile/#/308266/")
time.sleep(0.1)  # 페이지 로딩 대기 (필요 시 더 길게 조정)

# 렌더링된 페이지 소스 가져오기
soup = BeautifulSoup(driver.page_source, 'html.parser')

# 이미지 div 추출
photo_divs = soup.find_all('div', class_='photo')
for div in photo_divs:
    style = div.get('style', '')
    image_urls = re.findall(r"url\('([^']+)'\)", style)
    for idx, image_url in enumerate(image_urls):
        print(f"이미지 URL: {image_url}")

driver.quit()
# Out:
# ---------------------------------------------------------------------------
# WebDriverException                        Traceback (most recent call last)
# Cell In[24], line 10
#       8 # 크롬 드라이버 경로 설정
#       9 service = Service('C:\Program Files\Google\Chrome\Application\chrome.exe')  # 👉 크롬드라이버 경로로 수정하세요
# ---> 10 driver = webdriver.Chrome(service=service)
#      12 # 요기요 매장 페이지 접속
#      13 driver.get("https://www.yogiyo.co.kr/mobile/#/308266/")
#
# File ~\anaconda3\lib\site-packages\selenium\webdriver\chrome\webdriver.py:47, in WebDriver.__init__(self, options, service, keep_alive)
#      44 service = service if service else Service()
#      45 options = options if options else Options()
# ---> 47 super().__init__(
#      48     browser_name=DesiredCapabilities.CHROME["browserName"],
#      49     vendor_prefix="goog",
#      50     options=options,
#      51     service=service,
#      52     keep_alive=keep_alive,
#      53 )
#
# ...
