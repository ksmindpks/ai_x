# %%
from IPython.display import display, HTML 
display(HTML("""
<style>
div.container{width:86% !important;}
div.cell.code_cell.rendered{width:100%;}
div.CodeMirror {font-family:Consolas; font-size:15pt;}
div.output {font-size:15pt; font-weight:bold;}
div.input {font-family:Consolas; font-size:15pt;}
div.prompt {min-width:70px;}
div#toc-wrapper{padding-top:120px;}
div.text_cell_render ul li{font-size:12pt;padding:5px;}
table.dataframe{font-size:15px;}
</style>
"""))
# Out:
# <style>
# div.container{width:86% !important;}
# div.cell.code_cell.rendered{width:100%;}
# div.CodeMirror {font-family:Consolas; font-size:15pt;}
# div.output {font-size:15pt; font-weight:bold;}
# div.input {font-family:Consolas; font-size:15pt;}
# div.prompt {min-width:70px;}
# div#toc-wrapper{padding-top:120px;}
# div.text_cell_render ul li{font-size:12pt;padding:5px;}
# table.dataframe{font-size:15px;}
# </style>

# %%
import re
import time
from bs4 import BeautifulSoup
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.common.by import By
from selenium.webdriver.common.keys import Keys

# 크롬 드라이버 경로 설정
driver = webdriver.Chrome()
driver.get('https://www.yogiyo.co.kr/')
time.sleep(0.1)  # 페이지 로딩 대기 (필요 시 더 길게 조정)

elem = driver.find_element(By.CLASS_NAME, 'btn.btn-default.ico-loc').click()
time.sleep(0.1)

# %%
# 따로 땔 줄 몰라서 일단 분리 실행
elem = driver.find_element(By.CLASS_NAME, 'item.clearfix').click()
time.sleep(0.1)

# %%
# 렌더링된 페이지 소스 가져오기
soup = BeautifulSoup(driver.page_source, 'html.parser')

# 이미지 div 추출
photo_divs = soup.find_all('div', class_='photo')

for div in photo_divs:
    style = div.get('style', '')
    image_urls = re.findall(r"url\('([^']+)'\)", style)
    for idx, image_url in enumerate(image_urls):
        print(f"이미지 URL: {image_url}")
driver.quit()
# Out:
# 이미지 URL: https://images.yogiyo.co.kr/image/yogiyo/PARTNER_FR_IMG/%EC%B2%AD%EB%85%84%ED%94%BC%EC%9E%90/2025-02-28/%EC%A0%9C%ED%9C%B4FR_20250227_%EC%B2%AD%EB%85%84%ED%94%BC%EC%9E%90_%EB%82%98%EB%A7%8C%EC%9D%98-%EC%82%AC%EC%83%89%ED%94%BC%EC%9E%90L_1080x640.jpg?width=384&height=273&quality=100
# 이미지 URL: image/ic_photomenu_default.png
# 이미지 URL: https://images.yogiyo.co.kr/image/yogiyo/PARTNER_FR_IMG/%EC%B2%AD%EB%85%84%ED%94%BC%EC%9E%90/2024-07-09/%EC%A0%9C%ED%9C%B4FR_20240709_%EC%B2%AD%EB%85%84%ED%94%BC%EC%9E%90_%EB%B0%98%EB%B0%98%EC%98%A4%EB%A6%AC%EC%A7%80%EB%84%90L_1080x640.jpg?width=384&height=273&quality=100
# 이미지 URL: image/ic_photomenu_default.png
# ...
