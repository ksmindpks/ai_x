# %%
# pip install pymysql
import pymysql
conn = pymysql.connect(host='210.121.189.12',
                     user='remoteuser',
                     password='mbcdkzkepal0902!', 
                     database='devdb',
                     charset='utf8')

# %%
cursor = conn.cursor()
sql = "INSERT INTO PERSONAL VALUES (%s, %s, 'ceo', null, curdate(), 9000, 10, 40)"
pno = input("Enter the person number:")
pname = input("Enter the name of the person:")
cursor.execute(sql, (pno, pname))
print("수행결과 :", cursor.rowcount)
# cursor.close()
cursor.close()
# Out:
# 수행결과 : 1
